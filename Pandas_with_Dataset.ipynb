# %%
import pandas as pd

# %%
dataset= { 'cars':["BMW","Ford","Maruti"],
    'color_code':[1,3,5]
}
df=pd.DataFrame(dataset)
print(df)
# Out:
#      cars  color_code
# 0     BMW           1
# 1    Ford           3
# 2  Maruti           5

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
a=[1,7,2]
df1=pd.Series(a)
print(df1)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
b=[1,3,4]
mydf=pd.Series(b,index=["x","y","z"])
print(mydf)
# Out:
# x    1
# y    3
# z    4
# dtype: int64

# %%
print(mydf['y'])
# Out:
# 3

# %%
import pandas as pd
dict1={'A':1,'B':2,'C':3}
v1=pd.Series(dict1)
print(v1)
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
import pandas as pd
df3=pd.read_csv("C:\\Users\\sb193\\Downloads\\Mall_Customers.csv")
df3
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 245         246    Male   30                 297                      69
# 246         247  Female   56                 311                      14
# 247         248    Male   29                 313                      90
# 248         249  Female   19                 316                      32
# 249         250  Female   31                 325                      86
#
# [250 rows x 5 columns]

# %%
import pandas as pd
df4=pd.read_csv("C:\\Users\\sb193\\Downloads\\Health_data.csv")

# %%
df4.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df4.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df4.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# ## **Advanced Pandas**

# %%
df5=pd.read_csv("C:\\Users\\sb193\\Downloads\\SampleSuperstore.csv")

# %%
print(df5)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df5.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df5['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df5['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df5['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df5['Sub-Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
(df5['Sub-Category'].value_counts()).sort_values()
# Out:
# Sub-Category
# Copiers          68
# Machines        115
# Supplies        190
# Fasteners       217
# Bookcases       228
# Envelopes       254
# Tables          319
# Labels          364
# Appliances      466
# Chairs          617
# Accessories     775
# Art             796
# Storage         846
# Phones          889
# Furnishings     957
# Paper          1370
# Binders        1523
# Name: count, dtype: int64

# %%
(df5['Sub-Category'].value_counts()).sort_values(ascending=False)
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df5.sort_values('Category')
# Out:
#            Ship Mode      Segment        Country           City  \
# 0       Second Class     Consumer  United States      Henderson
# 8133  Standard Class    Corporate  United States         Dallas
# 1903     First Class    Corporate  United States    Springfield
# 6151    Second Class  Home Office  United States  San Francisco
# 6153     First Class    Corporate  United States   Philadelphia
# ...              ...          ...            ...            ...
# 1844  Standard Class     Consumer  United States        Seattle
# 3921    Second Class     Consumer  United States        Chicago
# 6173  Standard Class  Home Office  United States    Springfield
# 8348  Standard Class    Corporate  United States       Lawrence
# 2522  Standard Class  Home Office  United States  Oklahoma City
#
#               State  Postal Code   Region    Category Sub-Category     Sales  \
# 0          Kentucky        42420    South   Furniture    Bookcases   261.960
# 8133          Texas        75081  Central   Furniture  Furnishings    72.780
# 1903         Oregon        97477     West   Furniture       Chairs   478.480
# 6151     California        94110     West   Furniture    Bookcases  1198.330
# 6153   Pennsylvania        19120     East   Furniture  Furnishings    51.968
# ...             ...          ...      ...         ...          ...       ...
# 1844     Washington        98115     West  Technology  Accessories    90.570
# 3921       Illinois        60610  Central  Technology       Phones   359.976
# 6173       Missouri        65807  Central  Technology  Accessories    21.200
# 8348  Massachusetts         1841     East  Technology       Phones   209.500
# 2522       Oklahoma        73120  Central  Technology       Phones     5.500
#
#       Quantity  Discount   Profit
# 0            2      0.00  41.9136
# 8133         3      0.60 -70.9605
# 1903         2      0.20  47.8480
# 6151        10      0.15  70.4900
# 6153         2      0.20  10.3936
# ...        ...       ...      ...
# 1844         3      0.00  11.7741
# 3921         3      0.20  35.9976
# 6173         2      0.00   9.1160
# 8348        10      0.00  58.6600
# 2522         1      0.00   1.3750
#
# [9994 rows x 13 columns]

# %%
df5.sort_values(['Category','Profit'])
# Out:
#            Ship Mode      Segment        Country           City  \
# 9639    Second Class     Consumer  United States        Concord
# 27    Standard Class     Consumer  United States   Philadelphia
# 5320     First Class  Home Office  United States      Knoxville
# 8993  Standard Class    Corporate  United States       Columbia
# 463   Standard Class  Home Office  United States        Phoenix
# ...              ...          ...            ...            ...
# 8488    Second Class     Consumer  United States      Arlington
# 2623     First Class  Home Office  United States  New York City
# 4190  Standard Class     Consumer  United States         Newark
# 8153     First Class     Consumer  United States        Seattle
# 6826  Standard Class    Corporate  United States      Lafayette
#
#                State  Postal Code   Region    Category Sub-Category  \
# 9639  North Carolina        28027    South   Furniture       Tables
# 27      Pennsylvania        19140     East   Furniture    Bookcases
# 5320       Tennessee        37918    South   Furniture       Tables
# 8993       Tennessee        38401    South   Furniture       Tables
# 463          Arizona        85023     West   Furniture       Tables
# ...              ...          ...      ...         ...          ...
# 8488        Virginia        22204    South  Technology     Machines
# 2623        New York        10024     East  Technology      Copiers
# 4190        Delaware        19711     East  Technology      Copiers
# 8153      Washington        98115     West  Technology      Copiers
# 6826         Indiana        47905  Central  Technology      Copiers
#
#           Sales  Quantity  Discount     Profit
# 9639   4297.644        13       0.4 -1862.3124
# 27     3083.430         7       0.5 -1665.0522
# 5320   2314.116         7       0.4 -1002.7836
# 8993   1875.258         7       0.4  -968.8833
# 463    1272.630         6       0.5  -814.4832
# ...         ...       ...       ...        ...
# 8488   8749.950         5       0.0  2799.9840
# 2623  11199.968         4       0.2  3919.9888
# 4190  10499.970         3       0.0  5039.9856
# 8153  13999.960         4       0.0  6719.9808
# 6826  17499.950         5       0.0  8399.9760
#
# [9994 rows x 13 columns]

# %%
df5.shape
# Out:
# (9994, 13)

# %%
df5.drop_duplicates(subset=['Sub-Category'])
# Out:
#           Ship Mode    Segment        Country             City  \
# 0      Second Class   Consumer  United States        Henderson
# 1      Second Class   Consumer  United States        Henderson
# 2      Second Class  Corporate  United States      Los Angeles
# 3    Standard Class   Consumer  United States  Fort Lauderdale
# 4    Standard Class   Consumer  United States  Fort Lauderdale
# 5    Standard Class   Consumer  United States      Los Angeles
# 6    Standard Class   Consumer  United States      Los Angeles
# 7    Standard Class   Consumer  United States      Los Angeles
# 8    Standard Class   Consumer  United States      Los Angeles
# 9    Standard Class   Consumer  United States      Los Angeles
# 12   Standard Class   Consumer  United States          Concord
# 26     Second Class   Consumer  United States      Los Angeles
# 30   Standard Class   Consumer  United States     Philadelphia
# 53   Standard Class  Corporate  United States    New York City
# 138  Standard Class   Consumer  United States        Roseville
# 165  Standard Class   Consumer  United States      San Antonio
# 335    Second Class   Consumer  United States      Los Angeles
#
#               State  Postal Code   Region         Category Sub-Category  \
# 0          Kentucky        42420    South        Furniture    Bookcases
# 1          Kentucky        42420    South        Furniture       Chairs
# 2        California        90036     West  Office Supplies       Labels
# 3           Florida        33311    South        Furniture       Tables
# 4           Florida        33311    South  Office Supplies      Storage
# 5        California        90032     West        Furniture  Furnishings
# 6        California        90032     West  Office Supplies          Art
# 7        California        90032     West       Technology       Phones
# 8        California        90032     West  Office Supplies      Binders
# 9        California        90032     West  Office Supplies   Appliances
# 12   North Carolina        28027    South  Office Supplies        Paper
# 26       California        90049     West       Technology  Accessories
# 30     Pennsylvania        19140     East  Office Supplies    Envelopes
# 53         New York        10024     East  Office Supplies    Fasteners
# 138      California        95661     West  Office Supplies     Supplies
# 165           Texas        78207  Central       Technology     Machines
# 335      California        90045     West       Technology      Copiers
#
#          Sales  Quantity  Discount     Profit
# 0     261.9600         2      0.00    41.9136
# 1     731.9400         3      0.00   219.5820
# 2      14.6200         2      0.00     6.8714
# 3     957.5775         5      0.45  -383.0310
# 4      22.3680         2      0.20     2.5164
# 5      48.8600         7      0.00    14.1694
# 6       7.2800         4      0.00     1.9656
# 7     907.1520         6      0.20    90.7152
# 8      18.5040         3      0.20     5.7825
# 9     114.9000         5      0.00    34.4700
# 12     15.5520         3      0.20     5.4432
# 26     90.5700         3      0.00    11.7741
# 30      3.2640         2      0.20     1.1016
# 53     15.2600         7      0.00     6.2566
# 138    65.8800         6      0.00    18.4464
# 165  8159.9520         8      0.40 -1359.9920
# 335   959.9840         2      0.20   335.9944

# %%
df5.drop_duplicates(subset=['Sub-Category','Category']).shape
# Out:
# (17, 13)

# %%
df5.shape
# Out:
# (9994, 13)

# %%
categories=df5.groupby('Category')
categories

# %%
len(df5)
# Out:
# 9994

# %%
len(categories)
# Out:
# 3

# %%
categories.size()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# dtype: int64

# %%
categories.first()
# Out:
#                       Ship Mode    Segment        Country         City  \
# Category
# Furniture          Second Class   Consumer  United States    Henderson
# Office Supplies    Second Class  Corporate  United States  Los Angeles
# Technology       Standard Class   Consumer  United States  Los Angeles
#
#                       State  Postal Code Region Sub-Category    Sales  \
# Category
# Furniture          Kentucky        42420  South    Bookcases  261.960
# Office Supplies  California        90036   West       Labels   14.620
# Technology       California        90032   West       Phones  907.152
#
#                  Quantity  Discount   Profit
# Category
# Furniture               2       0.0  41.9136
# Office Supplies         2       0.0   6.8714
# Technology              6       0.2  90.7152

# %%
# Renaming & Combining

# %%
import pandas as pd
import numpy as np

df1=pd.read_csv("C:\\Users\\sb193\\Downloads\\Health_data.csv")

# %%
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df1.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#rename(), which lets  change column names.
df1.rename(columns={'Duration': 'Timing'})
# Out:
#      Timing  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# ..      ...    ...       ...       ...
# 164      60    105       140     290.8
# 165      60    110       145     300.0
# 166      60    115       145     310.2
# 167      75    120       150     320.4
# 168      75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#rename() lets you rename index values by specifying a index

df1.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Duration  Pulse  Maxpulse  Calories
# firstEntry         60    110       130     409.1
# secondEntry        60    117       145     479.0
# 2                  60    103       135     340.0
# 3                  45    109       175     282.4
# 4                  45    117       148     406.0
# ...               ...    ...       ...       ...
# 164                60    105       140     290.8
# 165                60    110       145     300.0
# 166                60    115       145     310.2
# 167                75    120       150     320.4
# 168                75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df2=pd.read_csv("C:\\Users\\sb193\\Downloads\\SampleSuperstore.csv")

# %%
df2.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
pd.concat([df1, df2])
# Out:
#       Duration  Pulse  Maxpulse  Calories       Ship Mode   Segment  \
# 0         60.0  110.0     130.0     409.1             NaN       NaN
# 1         60.0  117.0     145.0     479.0             NaN       NaN
# 2         60.0  103.0     135.0     340.0             NaN       NaN
# 3         45.0  109.0     175.0     282.4             NaN       NaN
# 4         45.0  117.0     148.0     406.0             NaN       NaN
# ...        ...    ...       ...       ...             ...       ...
# 9989       NaN    NaN       NaN       NaN    Second Class  Consumer
# 9990       NaN    NaN       NaN       NaN  Standard Class  Consumer
# 9991       NaN    NaN       NaN       NaN  Standard Class  Consumer
# 9992       NaN    NaN       NaN       NaN  Standard Class  Consumer
# 9993       NaN    NaN       NaN       NaN    Second Class  Consumer
#
#             Country         City       State  Postal Code Region  \
# 0               NaN          NaN         NaN          NaN    NaN
# 1               NaN          NaN         NaN          NaN    NaN
# 2               NaN          NaN         NaN          NaN    NaN
# 3               NaN          NaN         NaN          NaN    NaN
# 4               NaN          NaN         NaN          NaN    NaN
# ...             ...          ...         ...          ...    ...
# 9989  United States        Miami     Florida      33180.0  South
# 9990  United States   Costa Mesa  California      92627.0   West
# 9991  United States   Costa Mesa  California      92627.0   West
# 9992  United States   Costa Mesa  California      92627.0   West
# 9993  United States  Westminster  California      92683.0   West
#
#              Category Sub-Category    Sales  Quantity  Discount   Profit
# 0                 NaN          NaN      NaN       NaN       NaN      NaN
# 1                 NaN          NaN      NaN       NaN       NaN      NaN
# 2                 NaN          NaN      NaN       NaN       NaN      NaN
# 3                 NaN          NaN      NaN       NaN       NaN      NaN
# 4                 NaN          NaN      NaN       NaN       NaN      NaN
# ...               ...          ...      ...       ...       ...      ...
# 9989        Furniture  Furnishings   25.248       3.0       0.2   4.1028
# 9990        Furniture  Furnishings   91.960       2.0       0.0  15.6332
# 9991       Technology       Phones  258.576       2.0       0.2  19.3932
# 9992  Office Supplies        Paper   29.600       4.0       0.0  13.3200
# 9993  Office Supplies   Appliances  243.160       2.0       0.0  72.9480
#
# [10163 rows x 17 columns]

# %%
#join() lets you combine different DataFrame objects which have an index in common.

df1.join(df2)
# Out:
#      Duration  Pulse  Maxpulse  Calories       Ship Mode    Segment  \
# 0          60    110       130     409.1    Second Class   Consumer
# 1          60    117       145     479.0    Second Class   Consumer
# 2          60    103       135     340.0    Second Class  Corporate
# 3          45    109       175     282.4  Standard Class   Consumer
# 4          45    117       148     406.0  Standard Class   Consumer
# ..        ...    ...       ...       ...             ...        ...
# 164        60    105       140     290.8  Standard Class   Consumer
# 165        60    110       145     300.0  Standard Class   Consumer
# 166        60    115       145     310.2  Standard Class   Consumer
# 167        75    120       150     320.4  Standard Class   Consumer
# 168        75    125       150     330.4  Standard Class   Consumer
#
#            Country             City       State  Postal Code   Region  \
# 0    United States        Henderson    Kentucky        42420    South
# 1    United States        Henderson    Kentucky        42420    South
# 2    United States      Los Angeles  California        90036     West
# 3    United States  Fort Lauderdale     Florida        33311    South
# 4    United States  Fort Lauderdale     Florida        33311    South
# ..             ...              ...         ...          ...      ...
# 164  United States      San Antonio       Texas        78207  Central
# 165  United States      San Antonio       Texas        78207  Central
# 166  United States      San Antonio       Texas        78207  Central
# 167  United States      San Antonio       Texas        78207  Central
# 168  United States      San Antonio       Texas        78207  Central
#
#             Category Sub-Category      Sales  Quantity  Discount     Profit
# 0          Furniture    Bookcases   261.9600         2      0.00    41.9136
# 1          Furniture       Chairs   731.9400         3      0.00   219.5820
# 2    Office Supplies       Labels    14.6200         2      0.00     6.8714
# 3          Furniture       Tables   957.5775         5      0.45  -383.0310
# 4    Office Supplies      Storage    22.3680         2      0.20     2.5164
# ..               ...          ...        ...       ...       ...        ...
# 164  Office Supplies          Art     9.9360         3      0.20     2.7324
# 165       Technology     Machines  8159.9520         8      0.40 -1359.9920
# 166  Office Supplies      Storage   275.9280         3      0.20   -58.6347
# 167        Furniture       Chairs  1740.0600         9      0.30   -24.8580
# 168  Office Supplies          Art    32.0640         6      0.20     6.8136
#
# [169 rows x 17 columns]

# %%
import pandas as pd
df3=pd.read_csv("C:\\Users\\sb193\\Downloads\\SampleSuperstore.csv")

# %%
df3.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
